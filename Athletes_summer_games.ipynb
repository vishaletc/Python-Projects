# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/HP/Documents/SURAJ/Pandas files/Athletes_summer_games.csv");

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#         Unnamed: 0                                Name Sex   Age  \
# 0                0                           A Dijiang   M  24.0
# 1                1                            A Lamusi   M  23.0
# 2                2                 Gunnar Nielsen Aaby   M  24.0
# 3                3                Edgar Lindenau Aabye   M  34.0
# 4               26  Cornelia "Cor" Aalten (-Strannood)   F  18.0
# ...            ...                                 ...  ..   ...
# 237668       15116                   ZWOLINSKA Klaudia   F  22.0
# 237669       15117                        ZYKOVA Yulia   F  25.0
# 237670       15118                   ZYUZINA Ekaterina   F  24.0
# 237671       15119                     ZYZANSKA Sylwia   F  24.0
# 237672       15120                     ZYZANSKA Sylwia   F  24.0
#
#                   Team  NOC        Games  Year  Season         City  \
# 0                China  CHN  1992 Summer  1992  Summer    Barcelona
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                Name Sex   Age            Team  \
# 0           0                           A Dijiang   M  24.0           China
# 1           1                            A Lamusi   M  23.0           China
# 2           2                 Gunnar Nielsen Aaby   M  24.0         Denmark
# 3           3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden
# 4          26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands
#
#    NOC        Games  Year  Season         City       Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  CHN  2012 Summer  2012  Summer       London        Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.shape
# Out:
# (237673, 13)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=237673, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Sex', 'Age', 'Team', 'NOC', 'Games', 'Year',
#        'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Name           object
# Sex            object
# Age           float64
# Team           object
# NOC            object
# Games          object
# Year            int64
# Season         object
# City           object
# Sport          object
# Event          object
# Medal          object
# dtype: object

# %%
df.nunique()
# Out:
# Unnamed: 0    224790
# Name          127751
# Sex                2
# Age               74
# Team            1169
# NOC              233
# Games             30
# Year              30
# Season             1
# City              23
# Sport             70
# Event            957
# Medal              3
# dtype: int64

# %%
df['Name'].unique()
# Out:
# array(['A Dijiang', 'A Lamusi', 'Gunnar Nielsen Aaby', ...,
#        'ZYKOVA Yulia', 'ZYUZINA Ekaterina', 'ZYZANSKA Sylwia'],
#       dtype=object)

# %%
df.count()
# Out:
# Unnamed: 0    237673
# Name          237673
# Sex           237673
# Age           228484
# Team          237673
# NOC           237673
# Games         237673
# Year          237673
# Season        237673
# City          237673
# Sport         237673
# Event         237673
# Medal          36537
# dtype: int64

# %%
df['Team'].value_counts()
# Out:
# Team
# United States      15382
# Great Britain      10857
# France             10559
# Italy               8575
# Germany             7975
#                    ...
# Carabinier-5           1
# Pettit-Poucet-6        1
# Carabinier-15          1
# Breslau                1
# Hamburg                1
# Name: count, Length: 1169, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237673 entries, 0 to 237672
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  237673 non-null  int64
#  1   Name        237673 non-null  object
#  2   Sex         237673 non-null  object
#  3   Age         228484 non-null  float64
#  4   Team        237673 non-null  object
#  5   NOC         237673 non-null  object
#  6   Games       237673 non-null  object
#  7   Year        237673 non-null  int64
#  8   Season      237673 non-null  object
#  9   City        237673 non-null  object
#  10  Sport       237673 non-null  object
#  11  Event       237673 non-null  object
#  12  Medal       36537 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 23.6+ MB

# %%
df['Sport'].nunique()
# Out:
# 70

# %%
df.head(3)
# Out:
#    Unnamed: 0                 Name Sex   Age     Team  NOC        Games  Year  \
# 0           0            A Dijiang   M  24.0    China  CHN  1992 Summer  1992
# 1           1             A Lamusi   M  23.0    China  CHN  2012 Summer  2012
# 2           2  Gunnar Nielsen Aaby   M  24.0  Denmark  DEN  1920 Summer  1920
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
# 2  Summer  Antwerpen    Football       Football Men's Football   NaN

# %%
df.nunique()
# Out:
# Unnamed: 0    224790
# Name          127751
# Sex                2
# Age               74
# Team            1169
# NOC              233
# Games             30
# Year              30
# Season             1
# City              23
# Sport             70
# Event            957
# Medal              3
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Sex', 'Age', 'Team', 'NOC', 'Games', 'Year',
#        'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df['Medal'].value_counts()
# Out:
# Medal
# Bronze    12276
# Gold      12259
# Silver    12002
# Name: count, dtype: int64

# %%
df[df['Medal']== "Gold"].head(6)
# Out:
#     Unnamed: 0                       Name Sex   Age            Team  NOC  \
# 3            3       Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 16          42    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 18          44    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 22          48    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 33          79  Ragnhild Margrethe Aamodt   F  27.0          Norway  NOR
# 60         117        Thomas Valentin Aas   M  25.0          Taifun  NOR
#
#           Games  Year  Season       City       Sport  \
# 3   1900 Summer  1900  Summer      Paris  Tug-Of-War
# 16  1948 Summer  1948  Summer     London  Gymnastics
# 18  1948 Summer  1948  Summer     London  Gymnastics
# 22  1948 Summer  1948  Summer     London  Gymnastics
# 33  2008 Summer  2008  Summer    Beijing    Handball
# 60  1912 Summer  1912  Summer  Stockholm     Sailing
#
#                                Event Medal
# ...

# %%
df.groupby('Medal').get_group('Gold')
# Out:
#         Unnamed: 0                       Name Sex   Age            Team  NOC  \
# 3                3       Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 16              42    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 18              44    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 22              48    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 33              79  Ragnhild Margrethe Aamodt   F  27.0          Norway  NOR
# ...            ...                        ...  ..   ...             ...  ...
# 237600       15048              ZHONG Tianshi   F  30.0           China  CHN
# 237613       15061                ZHU Xueying   F  23.0           China  CHN
# 237643       15091         ZOLOTIC Anastasija   F  18.0   United States  USA
# 237652       15100               ZOU Jingyuan   M  23.0           China  CHN
# 237664       15112           ZVEREV Alexander   M  24.0         Germany  GER
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                Name Sex   Age            Team  \
# 0           0                           A Dijiang   M  24.0           China
# 1           1                            A Lamusi   M  23.0           China
# 2           2                 Gunnar Nielsen Aaby   M  24.0         Denmark
# 3           3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden
# 4          26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands
#
#    NOC        Games  Year  Season         City       Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  CHN  2012 Summer  2012  Summer       London        Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# ...

# %%
df[df['City']=="London"]
# Out:
#         Unnamed: 0                            Name Sex   Age        Team  NOC  \
# 1                1                        A Lamusi   M  23.0       China  CHN
# 15              41         Paavo Johannes Aaltonen   M  28.0     Finland  FIN
# 16              42         Paavo Johannes Aaltonen   M  28.0     Finland  FIN
# 17              43         Paavo Johannes Aaltonen   M  28.0     Finland  FIN
# 18              44         Paavo Johannes Aaltonen   M  28.0     Finland  FIN
# ...            ...                             ...  ..   ...         ...  ...
# 222499      271023                   Marc Zwiebler   M  28.0     Germany  GER
# 222506      271030  John Michael "Jack" Zwierewich   M  19.0      Canada  CAN
# 222520      271052   Viktoriya Viktorovna Zyabkina   F  19.0  Kazakhstan  KAZ
# 222539      271090                    Dominik ycki   M  38.0      Poland  POL
# 222540      271091              ukasz Tomasz ygado   M  32.0      Poland  POL
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Name               0
# Sex                0
# Age             9189
# Team               0
# NOC                0
# Games              0
# Year               0
# Season             0
# City               0
# Sport              0
# Event              0
# Medal         201136
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Unnamed: 0    237673
# Name          237673
# Sex           237673
# Age           228484
# Team          237673
# NOC           237673
# Games         237673
# Year          237673
# Season        237673
# City          237673
# Sport         237673
# Event         237673
# Medal          36537
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                                Name Sex   Age            Team  \
# 0           0                           A Dijiang   M  24.0           China
# 1           1                            A Lamusi   M  23.0           China
# 2           2                 Gunnar Nielsen Aaby   M  24.0         Denmark
# 3           3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden
# 4          26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands
#
#    NOC        Games  Year  Season         City       Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  CHN  2012 Summer  2012  Summer       London        Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.rename(columns = {'Event':'Events','Medal':'Medals'},inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0                                Name Sex   Age            Team  \
# 0           0                           A Dijiang   M  24.0           China
# 1           1                            A Lamusi   M  23.0           China
# 2           2                 Gunnar Nielsen Aaby   M  24.0         Denmark
# 3           3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden
# 4          26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands
#
#    NOC        Games  Year  Season         City       Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  CHN  2012 Summer  2012  Summer       London        Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                          Events Medals
# 0   Basketball Men's Basketball    NaN
# 1  Judo Men's Extra-Lightweight    NaN
# ...

# %%
df.Age.mean()
# Out:
# np.float64(25.746266697011606)

# %%
df.Age.std()
# Out:
# np.float64(6.638720481190597)

# %%
df['Age'].var()
# Out:
# np.float64(44.07260962737951)

# %%
df['Sport'].value_counts().head(10)
# Out:
# Sport
# Athletics     40942
# Gymnastics    26707
# Swimming      24829
# Shooting      12025
# Fencing       11154
# Rowing        11121
# Cycling       10859
# Wrestling      7443
# Football       7353
# Sailing        6936
# Name: count, dtype: int64

# %%
df[df['Sport'].str.contains('Basketball')]
# Out:
#         Unnamed: 0                                Name Sex   Age  \
# 0                0                           A Dijiang   M  24.0
# 105            167                   Tamara Abalde Daz   F  19.0
# 187            250               Youssef Mohamed Abbas   M  31.0
# 200            264                    Alessandro Abbio   M  29.0
# 277            346  Ahmed El-Sayed Abdel Hamid Mobarak   M  25.0
# ...            ...                                 ...  ..   ...
# 237377       14825                     YOUNG Jacquelyn   F  23.0
# 237469       14917                 ZAMOJSKI Przemyslaw   M  34.0
# 237566       15014                            ZHANG Ru   F  21.0
# 237584       15032                       ZHANG Zhiting   F  25.0
# 237658       15106                      ZUEV Alexander   M  24.0
#
#                  Team  NOC        Games  Year  Season       City  \
# 0               China  CHN  1992 Summer  1992  Summer  Barcelona
# ...

# %%
df[(df['Age']>30) & (df['Sport']=="Athletics")]
# Out:
#         Unnamed: 0                           Name Sex   Age           Team  \
# 31              57           Timo Antero Aaltonen   M  31.0        Finland
# 140            202              Georgia Abatzidou   F  35.0         Greece
# 253            322  Abdelgani Hassan Abdel Fattah   M  31.0          Egypt
# 385            454                    Youcef Abdi   M  34.0      Australia
# 399            468    Abdihakim "Abdi" Abdirahman   M  31.0  United States
# ...            ...                            ...  ..   ...            ...
# 237296       14744                  YARIGO Noelie   F  35.0          Benin
# 237320       14768                    YEGO Julius   M  32.0          Kenya
# 237450       14898                     ZAGRE Anne   F  31.0        Belgium
# 237486       14934             ZARCO ALVAREZ Ivan   M  37.0       Honduras
# 237631       15079                  ZIUKAS Marius   M  36.0      Lithuania
#
#         NOC        Games  Year  Season      City      Sport  \
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Sex, Age, Team, NOC, Games, Year, Season, City, Sport, Events, Medals]
# Index: []

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (237673, 13)

# %%
df[df['Name'].isin(['Basketball'])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Sex, Age, Team, NOC, Games, Year, Season, City, Sport, Events, Medals]
# Index: []

# %%
df[df['Name'].str.contains('YEGO Julius')]
# Out:
#         Unnamed: 0         Name Sex   Age   Team  NOC        Games  Year  \
# 237320       14768  YEGO Julius   M  32.0  Kenya  KEN  2020 Summer  2020
#
#         Season   City      Sport               Events Medals
# 237320  Summer  Tokyo  Athletics  Men's Javelin Throw    NaN

# %%
df_new = df.dropna(inplace = True)

# %%
df.head(5)
# Out:
#     Unnamed: 0                     Name Sex   Age            Team  NOC  \
# 3            3     Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 12          37     Arvo Ossian Aaltonen   M  30.0         Finland  FIN
# 13          38     Arvo Ossian Aaltonen   M  30.0         Finland  FIN
# 15          41  Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 16          42  Paavo Johannes Aaltonen   M  28.0         Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 3   1900 Summer  1900  Summer      Paris  Tug-Of-War
# 12  1920 Summer  1920  Summer  Antwerpen    Swimming
# 13  1920 Summer  1920  Summer  Antwerpen    Swimming
# 15  1948 Summer  1948  Summer     London  Gymnastics
# 16  1948 Summer  1948  Summer     London  Gymnastics
#
#                                     Events  Medals
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 12  Swimming Men's 200 metres Breaststroke  Bronze
# 13  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#         Unnamed: 0                     Name Sex   Age            Team  NOC  \
# 3                3     Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 12              37     Arvo Ossian Aaltonen   M  30.0         Finland  FIN
# 13              38     Arvo Ossian Aaltonen   M  30.0         Finland  FIN
# 15              41  Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 16              42  Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# ...            ...                      ...  ..   ...             ...  ...
# 237654       15102             ZOU Jingyuan   M  23.0           China  CHN
# 237657       15105         ZUBIMENDI Martin   M  22.0           Spain  ESP
# 237658       15106           ZUEV Alexander   M  24.0          Russia  ROC
# 237664       15112         ZVEREV Alexander   M  24.0         Germany  GER
# 237669       15117             ZYKOVA Yulia   F  25.0          Russia  ROC
#
#               Games  Year  Season       City                Sport  \
# ...

# %%
df.head()
# Out:
#     Unnamed: 0                     Name Sex   Age            Team  NOC  \
# 3            3     Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 12          37     Arvo Ossian Aaltonen   M  30.0         Finland  FIN
# 13          38     Arvo Ossian Aaltonen   M  30.0         Finland  FIN
# 15          41  Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 16          42  Paavo Johannes Aaltonen   M  28.0         Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 3   1900 Summer  1900  Summer      Paris  Tug-Of-War
# 12  1920 Summer  1920  Summer  Antwerpen    Swimming
# 13  1920 Summer  1920  Summer  Antwerpen    Swimming
# 15  1948 Summer  1948  Summer     London  Gymnastics
# 16  1948 Summer  1948  Summer     London  Gymnastics
#
#                                     Events  Medals
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 12  Swimming Men's 200 metres Breaststroke  Bronze
# 13  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#         Unnamed: 0                     Name Sex   Age            Team  NOC  \
# 3                3     Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 12              37     Arvo Ossian Aaltonen   M  30.0         Finland  FIN
# 13              38     Arvo Ossian Aaltonen   M  30.0         Finland  FIN
# 15              41  Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 16              42  Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# ...            ...                      ...  ..   ...             ...  ...
# 237654       15102             ZOU Jingyuan   M  23.0           China  CHN
# 237657       15105         ZUBIMENDI Martin   M  22.0           Spain  ESP
# 237658       15106           ZUEV Alexander   M  24.0          Russia  ROC
# 237664       15112         ZVEREV Alexander   M  24.0         Germany  GER
# 237669       15117             ZYKOVA Yulia   F  25.0          Russia  ROC
#
#               Games  Year  Season       City                Sport  \
# ...
